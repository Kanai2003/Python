# %%
from dash import Dash, dcc, html, Input, Output, State, callback 
import numpy as np 
import pandas as pd 
import plotly.graph_objs as go 
from datetime import datetime as dt 
from datetime import timedelta

# %%
cryptoDict = dict( 
    BTC = "Bitcoin", 
    ETH = "Ethereum", 
    BNB = "Binance", 
    DOGE = "Dogecoin" 
)

# %%
app = Dash(__name__);

# %%
app.layout = html.Div([
 
    dcc.Dropdown( 
        id = 'crypto-dropdown', 
        options = list(map(lambda key: {'label': cryptoDict[key], 'value': key}, cryptoDict.keys())), 
        value = "BTC", 
        placeholder = "Select a crypto", 
    ), 
 
    html.Div(children="", id='stock'), 
 
])

# %%
@callback( 
    Output(component_id='stock', component_property="children"), 
    Input(component_id='crypto-dropdown', component_property="value"),
    
) 
def update_text(user_selected): 
 
    df = pd.read_csv(f'../data/{user_selected}-USD.csv') 
 
     
    return html.Div(children =[
        html.Div(id="card", children=[
            html.H2(f"{cryptoDict[user_selected]} {user_selected} USD", id="crypto-name"),
            html.H1(round(float(df.iloc[-1]['Close']), 2), id="crypto-price")
        ]),
        dcc.Graph(
        id='stock-visualizer', 
        figure = { 
            'data' : [ 
                go.Candlestick(x=df['Date'], 
                    open=df['Open'], 
                    high=df['High'], 
                    low=df['Low'], 
                    close=df['Close'] 
                ) 
            ], 
             'layout' : go.Layout( 
                xaxis=dict( 
                    rangeselector=dict( 
                        buttons=list([ 
                            dict(count = 7, 
                                label='1W', 
                                step="day", 
                                stepmode="backward"), 
                            dict(count=1, 
                                label="1M", 
                                step="month", 
                                stepmode="backward"), 
                            dict(count=6, 
                                label="6M", 
                                step="month", 
                                stepmode="backward"), 
                            dict(count=1, 
                                label="YTD", 
                                step="year", 
                                stepmode="todate"), 
                            dict(count=1, 
                                label="1Y", 
                                step="year", 
                                stepmode="backward"), 
                            dict(step="all") 
                        ]) 
                    ), 
                    rangeslider=dict( 
                        visible=True 
                    ), 
                    type="date", 
                     
                ), 
 
                yaxis = dict(fixedrange = False) 
            ) 
              
        },
    ), ])

# %%
if __name__ == "__main__": 
    app.run_server(port='8000')
# Out:
# Dash is running on http://127.0.0.1:8000/
#
# Dash is running on http://127.0.0.1:8000/
#
# Dash is running on http://127.0.0.1:8000/
#
# Dash is running on http://127.0.0.1:8000/
#
# Dash is running on http://127.0.0.1:8000/
#
# Dash is running on http://127.0.0.1:8000/
#
# Dash is running on http://127.0.0.1:8000/
#
# Dash is running on http://127.0.0.1:8000/
#
# Dash is running on http://127.0.0.1:8000/
#
# Dash is running on http://127.0.0.1:8000/
#
# Dash is running on http://127.0.0.1:8000/
#
# Dash is running on http://127.0.0.1:8000/
#
# Dash is running on http://127.0.0.1:8000/
#
# Dash is running on http://127.0.0.1:8000/
#
# Dash is running on http://127.0.0.1:8000/
#
# Dash is running on http://127.0.0.1:8000/
#
# Dash is running on http://127.0.0.1:8000/
#
# Dash is running on http://127.0.0.1:8000/
#
# Dash is running on http://127.0.0.1:8000/
#
# Dash is running on http://127.0.0.1:8000/
#
# Dash is running on http://127.0.0.1:8000/
#
# Dash is running on http://127.0.0.1:8000/
#
# Dash is running on http://127.0.0.1:8000/
#
#  * Serving Flask app "__main__" (lazy loading)
#  * Environment: production
#    WARNING: This is a development server. Do not use it in a production deployment.
#    Use a production WSGI server instead.
#  * Debug mode: off
#  * Running on http://127.0.0.1:8000/ (Press CTRL+C to quit)
# 127.0.0.1 - - [16/Jan/2023 04:00:07] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [16/Jan/2023 04:00:07] "GET /_dash-layout HTTP/1.1" 200 -
# 127.0.0.1 - - [16/Jan/2023 04:00:07] "GET /_dash-dependencies HTTP/1.1" 200 -
# 127.0.0.1 - - [16/Jan/2023 04:00:07] "GET /_favicon.ico?v=2.7.1 HTTP/1.1" 200 -
# 127.0.0.1 - - [16/Jan/2023 04:00:07] "GET /_dash-component-suites/dash/dcc/async-dropdown.js HTTP/1.1" 200 -
# 127.0.0.1 - - [16/Jan/2023 04:00:07] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [16/Jan/2023 04:00:07] "GET /_dash-component-suites/dash/dcc/async-graph.js HTTP/1.1" 200 -
# 127.0.0.1 - - [16/Jan/2023 04:00:07] "GET /_dash-component-suites/dash/dcc/async-plotlyjs.js HTTP/1.1" 200 -
# 127.0.0.1 - - [16/Jan/2023 04:01:22] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [16/Jan/2023 04:01:22] "GET /assets/style.css?m=1673821878.4155736 HTTP/1.1" 200 -
# 127.0.0.1 - - [16/Jan/2023 04:01:22] "GET /_dash-layout HTTP/1.1" 200 -
# 127.0.0.1 - - [16/Jan/2023 04:01:22] "GET /_dash-dependencies HTTP/1.1" 200 -
# 127.0.0.1 - - [16/Jan/2023 04:01:23] "GET /_favicon.ico?v=2.7.1 HTTP/1.1" 200 -
# 127.0.0.1 - - [16/Jan/2023 04:01:23] "GET /_dash-component-suites/dash/dcc/async-dropdown.js HTTP/1.1" 200 -
# 127.0.0.1 - - [16/Jan/2023 04:01:23] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [16/Jan/2023 04:01:23] "GET /_dash-component-suites/dash/dcc/async-graph.js HTTP/1.1" 200 -
# 127.0.0.1 - - [16/Jan/2023 04:01:23] "GET /_dash-component-suites/dash/dcc/async-plotlyjs.js HTTP/1.1" 200 -
# 127.0.0.1 - - [16/Jan/2023 04:01:35] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [16/Jan/2023 04:01:35] "GET /assets/style.css?m=1673821892.3927505 HTTP/1.1" 200 -
# 127.0.0.1 - - [16/Jan/2023 04:01:35] "GET /_dash-layout HTTP/1.1" 200 -
# 127.0.0.1 - - [16/Jan/2023 04:01:35] "GET /_dash-dependencies HTTP/1.1" 200 -
# 127.0.0.1 - - [16/Jan/2023 04:01:35] "GET /_favicon.ico?v=2.7.1 HTTP/1.1" 200 -
# 127.0.0.1 - - [16/Jan/2023 04:01:35] "GET /_dash-component-suites/dash/dcc/async-dropdown.js HTTP/1.1" 200 -
# 127.0.0.1 - - [16/Jan/2023 04:01:35] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [16/Jan/2023 04:01:35] "GET /_dash-component-suites/dash/dcc/async-graph.js HTTP/1.1" 200 -
# 127.0.0.1 - - [16/Jan/2023 04:01:35] "GET /_dash-component-suites/dash/dcc/async-plotlyjs.js HTTP/1.1" 200 -
# Exception on /_dash-update-component [POST]
# Traceback (most recent call last):
#   File "c:\Users\Driptanil\anaconda3\lib\site-packages\flask\app.py", line 2447, in wsgi_app
#     response = self.full_dispatch_request()
#   File "c:\Users\Driptanil\anaconda3\lib\site-packages\flask\app.py", line 1952, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "c:\Users\Driptanil\anaconda3\lib\site-packages\flask\app.py", line 1821, in handle_user_exception
#     reraise(exc_type, exc_value, tb)
#   File "c:\Users\Driptanil\anaconda3\lib\site-packages\flask\_compat.py", line 39, in reraise
#     raise value
#   File "c:\Users\Driptanil\anaconda3\lib\site-packages\flask\app.py", line 1950, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "c:\Users\Driptanil\anaconda3\lib\site-packages\flask\app.py", line 1936, in dispatch_request
#     return self.view_functions[rule.endpoint](**req.view_args)
#   File "c:\Users\Driptanil\anaconda3\lib\site-packages\dash\dash.py", line 1274, in dispatch
#     ctx.run(
#   File "c:\Users\Driptanil\anaconda3\lib\site-packages\dash\_callback.py", line 440, in add_context
#     output_value = func(*func_args, **func_kwargs)  # %% callback invoked %%
#   File "C:\Users\Driptanil\AppData\Local\Temp\ipykernel_9964\205751449.py", line 8, in update_text
#     df = pd.read_csv(f'../data/{user_selected}-USD.csv')
#   File "c:\Users\Driptanil\anaconda3\lib\site-packages\pandas\util\_decorators.py", line 311, in wrapper
#     return func(*args, **kwargs)
#   File "c:\Users\Driptanil\anaconda3\lib\site-packages\pandas\io\parsers\readers.py", line 680, in read_csv
#     return _read(filepath_or_buffer, kwds)
#   File "c:\Users\Driptanil\anaconda3\lib\site-packages\pandas\io\parsers\readers.py", line 575, in _read
#     parser = TextFileReader(filepath_or_buffer, **kwds)
#   File "c:\Users\Driptanil\anaconda3\lib\site-packages\pandas\io\parsers\readers.py", line 933, in __init__
#     self._engine = self._make_engine(f, self.engine)
#   File "c:\Users\Driptanil\anaconda3\lib\site-packages\pandas\io\parsers\readers.py", line 1217, in _make_engine
#     self.handles = get_handle(  # type: ignore[call-overload]
#   File "c:\Users\Driptanil\anaconda3\lib\site-packages\pandas\io\common.py", line 789, in get_handle
#     handle = open(
# FileNotFoundError: [Errno 2] No such file or directory: '../data/None-USD.csv'
# Exception on /_dash-update-component [POST]
# Traceback (most recent call last):
#   File "c:\Users\Driptanil\anaconda3\lib\site-packages\flask\app.py", line 2447, in wsgi_app
#     response = self.full_dispatch_request()
#   File "c:\Users\Driptanil\anaconda3\lib\site-packages\flask\app.py", line 1952, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "c:\Users\Driptanil\anaconda3\lib\site-packages\flask\app.py", line 1821, in handle_user_exception
#     reraise(exc_type, exc_value, tb)
#   File "c:\Users\Driptanil\anaconda3\lib\site-packages\flask\_compat.py", line 39, in reraise
#     raise value
#   File "c:\Users\Driptanil\anaconda3\lib\site-packages\flask\app.py", line 1950, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "c:\Users\Driptanil\anaconda3\lib\site-packages\flask\app.py", line 1936, in dispatch_request
#     return self.view_functions[rule.endpoint](**req.view_args)
#   File "c:\Users\Driptanil\anaconda3\lib\site-packages\dash\dash.py", line 1274, in dispatch
#     ctx.run(
#   File "c:\Users\Driptanil\anaconda3\lib\site-packages\dash\_callback.py", line 440, in add_context
#     output_value = func(*func_args, **func_kwargs)  # %% callback invoked %%
#   File "C:\Users\Driptanil\AppData\Local\Temp\ipykernel_9964\205751449.py", line 8, in update_text
#     df = pd.read_csv(f'../data/{user_selected}-USD.csv')
#   File "c:\Users\Driptanil\anaconda3\lib\site-packages\pandas\util\_decorators.py", line 311, in wrapper
#     return func(*args, **kwargs)
#   File "c:\Users\Driptanil\anaconda3\lib\site-packages\pandas\io\parsers\readers.py", line 680, in read_csv
#     return _read(filepath_or_buffer, kwds)
#   File "c:\Users\Driptanil\anaconda3\lib\site-packages\pandas\io\parsers\readers.py", line 575, in _read
#     parser = TextFileReader(filepath_or_buffer, **kwds)
#   File "c:\Users\Driptanil\anaconda3\lib\site-packages\pandas\io\parsers\readers.py", line 933, in __init__
#     self._engine = self._make_engine(f, self.engine)
#   File "c:\Users\Driptanil\anaconda3\lib\site-packages\pandas\io\parsers\readers.py", line 1217, in _make_engine
#     self.handles = get_handle(  # type: ignore[call-overload]
#   File "c:\Users\Driptanil\anaconda3\lib\site-packages\pandas\io\common.py", line 789, in get_handle
#     handle = open(
# FileNotFoundError: [Errno 2] No such file or directory: '../data/None-USD.csv'
# Exception on /_dash-update-component [POST]
# Traceback (most recent call last):
#   File "c:\Users\Driptanil\anaconda3\lib\site-packages\flask\app.py", line 2447, in wsgi_app
#     response = self.full_dispatch_request()
#   File "c:\Users\Driptanil\anaconda3\lib\site-packages\flask\app.py", line 1952, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "c:\Users\Driptanil\anaconda3\lib\site-packages\flask\app.py", line 1821, in handle_user_exception
#     reraise(exc_type, exc_value, tb)
#   File "c:\Users\Driptanil\anaconda3\lib\site-packages\flask\_compat.py", line 39, in reraise
#     raise value
#   File "c:\Users\Driptanil\anaconda3\lib\site-packages\flask\app.py", line 1950, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "c:\Users\Driptanil\anaconda3\lib\site-packages\flask\app.py", line 1936, in dispatch_request
#     return self.view_functions[rule.endpoint](**req.view_args)
#   File "c:\Users\Driptanil\anaconda3\lib\site-packages\dash\dash.py", line 1274, in dispatch
#     ctx.run(
#   File "c:\Users\Driptanil\anaconda3\lib\site-packages\dash\_callback.py", line 440, in add_context
#     output_value = func(*func_args, **func_kwargs)  # %% callback invoked %%
#   File "C:\Users\Driptanil\AppData\Local\Temp\ipykernel_9964\205751449.py", line 8, in update_text
#     df = pd.read_csv(f'../data/{user_selected}-USD.csv')
#   File "c:\Users\Driptanil\anaconda3\lib\site-packages\pandas\util\_decorators.py", line 311, in wrapper
#     return func(*args, **kwargs)
#   File "c:\Users\Driptanil\anaconda3\lib\site-packages\pandas\io\parsers\readers.py", line 680, in read_csv
#     return _read(filepath_or_buffer, kwds)
#   File "c:\Users\Driptanil\anaconda3\lib\site-packages\pandas\io\parsers\readers.py", line 575, in _read
#     parser = TextFileReader(filepath_or_buffer, **kwds)
#   File "c:\Users\Driptanil\anaconda3\lib\site-packages\pandas\io\parsers\readers.py", line 933, in __init__
#     self._engine = self._make_engine(f, self.engine)
#   File "c:\Users\Driptanil\anaconda3\lib\site-packages\pandas\io\parsers\readers.py", line 1217, in _make_engine
#     self.handles = get_handle(  # type: ignore[call-overload]
#   File "c:\Users\Driptanil\anaconda3\lib\site-packages\pandas\io\common.py", line 789, in get_handle
#     handle = open(
# FileNotFoundError: [Errno 2] No such file or directory: '../data/None-USD.csv'
# Exception on /_dash-update-component [POST]
# Traceback (most recent call last):
#   File "c:\Users\Driptanil\anaconda3\lib\site-packages\flask\app.py", line 2447, in wsgi_app
#     response = self.full_dispatch_request()
#   File "c:\Users\Driptanil\anaconda3\lib\site-packages\flask\app.py", line 1952, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "c:\Users\Driptanil\anaconda3\lib\site-packages\flask\app.py", line 1821, in handle_user_exception
#     reraise(exc_type, exc_value, tb)
#   File "c:\Users\Driptanil\anaconda3\lib\site-packages\flask\_compat.py", line 39, in reraise
#     raise value
#   File "c:\Users\Driptanil\anaconda3\lib\site-packages\flask\app.py", line 1950, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "c:\Users\Driptanil\anaconda3\lib\site-packages\flask\app.py", line 1936, in dispatch_request
#     return self.view_functions[rule.endpoint](**req.view_args)
#   File "c:\Users\Driptanil\anaconda3\lib\site-packages\dash\dash.py", line 1274, in dispatch
#     ctx.run(
#   File "c:\Users\Driptanil\anaconda3\lib\site-packages\dash\_callback.py", line 440, in add_context
#     output_value = func(*func_args, **func_kwargs)  # %% callback invoked %%
#   File "C:\Users\Driptanil\AppData\Local\Temp\ipykernel_9964\205751449.py", line 8, in update_text
#     df = pd.read_csv(f'../data/{user_selected}-USD.csv')
#   File "c:\Users\Driptanil\anaconda3\lib\site-packages\pandas\util\_decorators.py", line 311, in wrapper
#     return func(*args, **kwargs)
#   File "c:\Users\Driptanil\anaconda3\lib\site-packages\pandas\io\parsers\readers.py", line 680, in read_csv
#     return _read(filepath_or_buffer, kwds)
#   File "c:\Users\Driptanil\anaconda3\lib\site-packages\pandas\io\parsers\readers.py", line 575, in _read
#     parser = TextFileReader(filepath_or_buffer, **kwds)
#   File "c:\Users\Driptanil\anaconda3\lib\site-packages\pandas\io\parsers\readers.py", line 933, in __init__
#     self._engine = self._make_engine(f, self.engine)
#   File "c:\Users\Driptanil\anaconda3\lib\site-packages\pandas\io\parsers\readers.py", line 1217, in _make_engine
#     self.handles = get_handle(  # type: ignore[call-overload]
#   File "c:\Users\Driptanil\anaconda3\lib\site-packages\pandas\io\common.py", line 789, in get_handle
#     handle = open(
# FileNotFoundError: [Errno 2] No such file or directory: '../data/None-USD.csv'
# Exception on /_dash-update-component [POST]
# Traceback (most recent call last):
#   File "c:\Users\Driptanil\anaconda3\lib\site-packages\flask\app.py", line 2447, in wsgi_app
#     response = self.full_dispatch_request()
#   File "c:\Users\Driptanil\anaconda3\lib\site-packages\flask\app.py", line 1952, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "c:\Users\Driptanil\anaconda3\lib\site-packages\flask\app.py", line 1821, in handle_user_exception
#     reraise(exc_type, exc_value, tb)
#   File "c:\Users\Driptanil\anaconda3\lib\site-packages\flask\_compat.py", line 39, in reraise
#     raise value
#   File "c:\Users\Driptanil\anaconda3\lib\site-packages\flask\app.py", line 1950, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "c:\Users\Driptanil\anaconda3\lib\site-packages\flask\app.py", line 1936, in dispatch_request
#     return self.view_functions[rule.endpoint](**req.view_args)
#   File "c:\Users\Driptanil\anaconda3\lib\site-packages\dash\dash.py", line 1274, in dispatch
#     ctx.run(
#   File "c:\Users\Driptanil\anaconda3\lib\site-packages\dash\_callback.py", line 440, in add_context
#     output_value = func(*func_args, **func_kwargs)  # %% callback invoked %%
#   File "C:\Users\Driptanil\AppData\Local\Temp\ipykernel_9964\205751449.py", line 8, in update_text
#     df = pd.read_csv(f'../data/{user_selected}-USD.csv')
#   File "c:\Users\Driptanil\anaconda3\lib\site-packages\pandas\util\_decorators.py", line 311, in wrapper
#     return func(*args, **kwargs)
#   File "c:\Users\Driptanil\anaconda3\lib\site-packages\pandas\io\parsers\readers.py", line 680, in read_csv
#     return _read(filepath_or_buffer, kwds)
#   File "c:\Users\Driptanil\anaconda3\lib\site-packages\pandas\io\parsers\readers.py", line 575, in _read
#     parser = TextFileReader(filepath_or_buffer, **kwds)
#   File "c:\Users\Driptanil\anaconda3\lib\site-packages\pandas\io\parsers\readers.py", line 933, in __init__
#     self._engine = self._make_engine(f, self.engine)
#   File "c:\Users\Driptanil\anaconda3\lib\site-packages\pandas\io\parsers\readers.py", line 1217, in _make_engine
#     self.handles = get_handle(  # type: ignore[call-overload]
#   File "c:\Users\Driptanil\anaconda3\lib\site-packages\pandas\io\common.py", line 789, in get_handle
#     handle = open(
# FileNotFoundError: [Errno 2] No such file or directory: '../data/None-USD.csv'
# Exception on /_dash-update-component [POST]
# Traceback (most recent call last):
#   File "c:\Users\Driptanil\anaconda3\lib\site-packages\flask\app.py", line 2447, in wsgi_app
#     response = self.full_dispatch_request()
#   File "c:\Users\Driptanil\anaconda3\lib\site-packages\flask\app.py", line 1952, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "c:\Users\Driptanil\anaconda3\lib\site-packages\flask\app.py", line 1821, in handle_user_exception
#     reraise(exc_type, exc_value, tb)
#   File "c:\Users\Driptanil\anaconda3\lib\site-packages\flask\_compat.py", line 39, in reraise
#     raise value
#   File "c:\Users\Driptanil\anaconda3\lib\site-packages\flask\app.py", line 1950, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "c:\Users\Driptanil\anaconda3\lib\site-packages\flask\app.py", line 1936, in dispatch_request
#     return self.view_functions[rule.endpoint](**req.view_args)
#   File "c:\Users\Driptanil\anaconda3\lib\site-packages\dash\dash.py", line 1274, in dispatch
#     ctx.run(
#   File "c:\Users\Driptanil\anaconda3\lib\site-packages\dash\_callback.py", line 440, in add_context
#     output_value = func(*func_args, **func_kwargs)  # %% callback invoked %%
#   File "C:\Users\Driptanil\AppData\Local\Temp\ipykernel_9964\205751449.py", line 8, in update_text
#     df = pd.read_csv(f'../data/{user_selected}-USD.csv')
#   File "c:\Users\Driptanil\anaconda3\lib\site-packages\pandas\util\_decorators.py", line 311, in wrapper
#     return func(*args, **kwargs)
#   File "c:\Users\Driptanil\anaconda3\lib\site-packages\pandas\io\parsers\readers.py", line 680, in read_csv
#     return _read(filepath_or_buffer, kwds)
#   File "c:\Users\Driptanil\anaconda3\lib\site-packages\pandas\io\parsers\readers.py", line 575, in _read
#     parser = TextFileReader(filepath_or_buffer, **kwds)
#   File "c:\Users\Driptanil\anaconda3\lib\site-packages\pandas\io\parsers\readers.py", line 933, in __init__
#     self._engine = self._make_engine(f, self.engine)
#   File "c:\Users\Driptanil\anaconda3\lib\site-packages\pandas\io\parsers\readers.py", line 1217, in _make_engine
#     self.handles = get_handle(  # type: ignore[call-overload]
#   File "c:\Users\Driptanil\anaconda3\lib\site-packages\pandas\io\common.py", line 789, in get_handle
#     handle = open(
# FileNotFoundError: [Errno 2] No such file or directory: '../data/None-USD.csv'
# Exception on /_dash-update-component [POST]
# Traceback (most recent call last):
#   File "c:\Users\Driptanil\anaconda3\lib\site-packages\flask\app.py", line 2447, in wsgi_app
#     response = self.full_dispatch_request()
#   File "c:\Users\Driptanil\anaconda3\lib\site-packages\flask\app.py", line 1952, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "c:\Users\Driptanil\anaconda3\lib\site-packages\flask\app.py", line 1821, in handle_user_exception
#     reraise(exc_type, exc_value, tb)
#   File "c:\Users\Driptanil\anaconda3\lib\site-packages\flask\_compat.py", line 39, in reraise
#     raise value
#   File "c:\Users\Driptanil\anaconda3\lib\site-packages\flask\app.py", line 1950, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "c:\Users\Driptanil\anaconda3\lib\site-packages\flask\app.py", line 1936, in dispatch_request
#     return self.view_functions[rule.endpoint](**req.view_args)
#   File "c:\Users\Driptanil\anaconda3\lib\site-packages\dash\dash.py", line 1274, in dispatch
#     ctx.run(
#   File "c:\Users\Driptanil\anaconda3\lib\site-packages\dash\_callback.py", line 440, in add_context
#     output_value = func(*func_args, **func_kwargs)  # %% callback invoked %%
#   File "C:\Users\Driptanil\AppData\Local\Temp\ipykernel_9964\205751449.py", line 8, in update_text
#     df = pd.read_csv(f'../data/{user_selected}-USD.csv')
#   File "c:\Users\Driptanil\anaconda3\lib\site-packages\pandas\util\_decorators.py", line 311, in wrapper
#     return func(*args, **kwargs)
#   File "c:\Users\Driptanil\anaconda3\lib\site-packages\pandas\io\parsers\readers.py", line 680, in read_csv
#     return _read(filepath_or_buffer, kwds)
#   File "c:\Users\Driptanil\anaconda3\lib\site-packages\pandas\io\parsers\readers.py", line 575, in _read
#     parser = TextFileReader(filepath_or_buffer, **kwds)
#   File "c:\Users\Driptanil\anaconda3\lib\site-packages\pandas\io\parsers\readers.py", line 933, in __init__
#     self._engine = self._make_engine(f, self.engine)
#   File "c:\Users\Driptanil\anaconda3\lib\site-packages\pandas\io\parsers\readers.py", line 1217, in _make_engine
#     self.handles = get_handle(  # type: ignore[call-overload]
#   File "c:\Users\Driptanil\anaconda3\lib\site-packages\pandas\io\common.py", line 789, in get_handle
#     handle = open(
# FileNotFoundError: [Errno 2] No such file or directory: '../data/None-USD.csv'
# Exception on /_dash-update-component [POST]
# Traceback (most recent call last):
#   File "c:\Users\Driptanil\anaconda3\lib\site-packages\flask\app.py", line 2447, in wsgi_app
#     response = self.full_dispatch_request()
#   File "c:\Users\Driptanil\anaconda3\lib\site-packages\flask\app.py", line 1952, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "c:\Users\Driptanil\anaconda3\lib\site-packages\flask\app.py", line 1821, in handle_user_exception
#     reraise(exc_type, exc_value, tb)
#   File "c:\Users\Driptanil\anaconda3\lib\site-packages\flask\_compat.py", line 39, in reraise
#     raise value
#   File "c:\Users\Driptanil\anaconda3\lib\site-packages\flask\app.py", line 1950, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "c:\Users\Driptanil\anaconda3\lib\site-packages\flask\app.py", line 1936, in dispatch_request
#     return self.view_functions[rule.endpoint](**req.view_args)
#   File "c:\Users\Driptanil\anaconda3\lib\site-packages\dash\dash.py", line 1274, in dispatch
#     ctx.run(
#   File "c:\Users\Driptanil\anaconda3\lib\site-packages\dash\_callback.py", line 440, in add_context
#     output_value = func(*func_args, **func_kwargs)  # %% callback invoked %%
#   File "C:\Users\Driptanil\AppData\Local\Temp\ipykernel_9964\205751449.py", line 8, in update_text
#     df = pd.read_csv(f'../data/{user_selected}-USD.csv')
#   File "c:\Users\Driptanil\anaconda3\lib\site-packages\pandas\util\_decorators.py", line 311, in wrapper
#     return func(*args, **kwargs)
#   File "c:\Users\Driptanil\anaconda3\lib\site-packages\pandas\io\parsers\readers.py", line 680, in read_csv
#     return _read(filepath_or_buffer, kwds)
#   File "c:\Users\Driptanil\anaconda3\lib\site-packages\pandas\io\parsers\readers.py", line 575, in _read
#     parser = TextFileReader(filepath_or_buffer, **kwds)
#   File "c:\Users\Driptanil\anaconda3\lib\site-packages\pandas\io\parsers\readers.py", line 933, in __init__
#     self._engine = self._make_engine(f, self.engine)
#   File "c:\Users\Driptanil\anaconda3\lib\site-packages\pandas\io\parsers\readers.py", line 1217, in _make_engine
#     self.handles = get_handle(  # type: ignore[call-overload]
#   File "c:\Users\Driptanil\anaconda3\lib\site-packages\pandas\io\common.py", line 789, in get_handle
#     handle = open(
# FileNotFoundError: [Errno 2] No such file or directory: '../data/None-USD.csv'
# Exception on /_dash-update-component [POST]
# Traceback (most recent call last):
#   File "c:\Users\Driptanil\anaconda3\lib\site-packages\flask\app.py", line 2447, in wsgi_app
#     response = self.full_dispatch_request()
#   File "c:\Users\Driptanil\anaconda3\lib\site-packages\flask\app.py", line 1952, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "c:\Users\Driptanil\anaconda3\lib\site-packages\flask\app.py", line 1821, in handle_user_exception
#     reraise(exc_type, exc_value, tb)
#   File "c:\Users\Driptanil\anaconda3\lib\site-packages\flask\_compat.py", line 39, in reraise
#     raise value
#   File "c:\Users\Driptanil\anaconda3\lib\site-packages\flask\app.py", line 1950, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "c:\Users\Driptanil\anaconda3\lib\site-packages\flask\app.py", line 1936, in dispatch_request
#     return self.view_functions[rule.endpoint](**req.view_args)
#   File "c:\Users\Driptanil\anaconda3\lib\site-packages\dash\dash.py", line 1274, in dispatch
#     ctx.run(
#   File "c:\Users\Driptanil\anaconda3\lib\site-packages\dash\_callback.py", line 440, in add_context
#     output_value = func(*func_args, **func_kwargs)  # %% callback invoked %%
#   File "C:\Users\Driptanil\AppData\Local\Temp\ipykernel_9964\205751449.py", line 8, in update_text
#     df = pd.read_csv(f'../data/{user_selected}-USD.csv')
#   File "c:\Users\Driptanil\anaconda3\lib\site-packages\pandas\util\_decorators.py", line 311, in wrapper
#     return func(*args, **kwargs)
#   File "c:\Users\Driptanil\anaconda3\lib\site-packages\pandas\io\parsers\readers.py", line 680, in read_csv
#     return _read(filepath_or_buffer, kwds)
#   File "c:\Users\Driptanil\anaconda3\lib\site-packages\pandas\io\parsers\readers.py", line 575, in _read
#     parser = TextFileReader(filepath_or_buffer, **kwds)
#   File "c:\Users\Driptanil\anaconda3\lib\site-packages\pandas\io\parsers\readers.py", line 933, in __init__
#     self._engine = self._make_engine(f, self.engine)
#   File "c:\Users\Driptanil\anaconda3\lib\site-packages\pandas\io\parsers\readers.py", line 1217, in _make_engine
#     self.handles = get_handle(  # type: ignore[call-overload]
#   File "c:\Users\Driptanil\anaconda3\lib\site-packages\pandas\io\common.py", line 789, in get_handle
#     handle = open(
# FileNotFoundError: [Errno 2] No such file or directory: '../data/None-USD.csv'
# Exception on /_dash-update-component [POST]
# Traceback (most recent call last):
#   File "c:\Users\Driptanil\anaconda3\lib\site-packages\flask\app.py", line 2447, in wsgi_app
#     response = self.full_dispatch_request()
#   File "c:\Users\Driptanil\anaconda3\lib\site-packages\flask\app.py", line 1952, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "c:\Users\Driptanil\anaconda3\lib\site-packages\flask\app.py", line 1821, in handle_user_exception
#     reraise(exc_type, exc_value, tb)
#   File "c:\Users\Driptanil\anaconda3\lib\site-packages\flask\_compat.py", line 39, in reraise
#     raise value
#   File "c:\Users\Driptanil\anaconda3\lib\site-packages\flask\app.py", line 1950, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "c:\Users\Driptanil\anaconda3\lib\site-packages\flask\app.py", line 1936, in dispatch_request
#     return self.view_functions[rule.endpoint](**req.view_args)
#   File "c:\Users\Driptanil\anaconda3\lib\site-packages\dash\dash.py", line 1274, in dispatch
#     ctx.run(
#   File "c:\Users\Driptanil\anaconda3\lib\site-packages\dash\_callback.py", line 440, in add_context
#     output_value = func(*func_args, **func_kwargs)  # %% callback invoked %%
#   File "C:\Users\Driptanil\AppData\Local\Temp\ipykernel_9964\205751449.py", line 8, in update_text
#     df = pd.read_csv(f'../data/{user_selected}-USD.csv')
#   File "c:\Users\Driptanil\anaconda3\lib\site-packages\pandas\util\_decorators.py", line 311, in wrapper
#     return func(*args, **kwargs)
#   File "c:\Users\Driptanil\anaconda3\lib\site-packages\pandas\io\parsers\readers.py", line 680, in read_csv
#     return _read(filepath_or_buffer, kwds)
#   File "c:\Users\Driptanil\anaconda3\lib\site-packages\pandas\io\parsers\readers.py", line 575, in _read
#     parser = TextFileReader(filepath_or_buffer, **kwds)
#   File "c:\Users\Driptanil\anaconda3\lib\site-packages\pandas\io\parsers\readers.py", line 933, in __init__
#     self._engine = self._make_engine(f, self.engine)
#   File "c:\Users\Driptanil\anaconda3\lib\site-packages\pandas\io\parsers\readers.py", line 1217, in _make_engine
#     self.handles = get_handle(  # type: ignore[call-overload]
#   File "c:\Users\Driptanil\anaconda3\lib\site-packages\pandas\io\common.py", line 789, in get_handle
#     handle = open(
# FileNotFoundError: [Errno 2] No such file or directory: '../data/None-USD.csv'
# Exception on /_dash-update-component [POST]
# Traceback (most recent call last):
#   File "c:\Users\Driptanil\anaconda3\lib\site-packages\flask\app.py", line 2447, in wsgi_app
#     response = self.full_dispatch_request()
#   File "c:\Users\Driptanil\anaconda3\lib\site-packages\flask\app.py", line 1952, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "c:\Users\Driptanil\anaconda3\lib\site-packages\flask\app.py", line 1821, in handle_user_exception
#     reraise(exc_type, exc_value, tb)
#   File "c:\Users\Driptanil\anaconda3\lib\site-packages\flask\_compat.py", line 39, in reraise
#     raise value
#   File "c:\Users\Driptanil\anaconda3\lib\site-packages\flask\app.py", line 1950, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "c:\Users\Driptanil\anaconda3\lib\site-packages\flask\app.py", line 1936, in dispatch_request
#     return self.view_functions[rule.endpoint](**req.view_args)
#   File "c:\Users\Driptanil\anaconda3\lib\site-packages\dash\dash.py", line 1274, in dispatch
#     ctx.run(
#   File "c:\Users\Driptanil\anaconda3\lib\site-packages\dash\_callback.py", line 440, in add_context
#     output_value = func(*func_args, **func_kwargs)  # %% callback invoked %%
#   File "C:\Users\Driptanil\AppData\Local\Temp\ipykernel_9964\205751449.py", line 8, in update_text
#     df = pd.read_csv(f'../data/{user_selected}-USD.csv')
#   File "c:\Users\Driptanil\anaconda3\lib\site-packages\pandas\util\_decorators.py", line 311, in wrapper
#     return func(*args, **kwargs)
#   File "c:\Users\Driptanil\anaconda3\lib\site-packages\pandas\io\parsers\readers.py", line 680, in read_csv
#     return _read(filepath_or_buffer, kwds)
#   File "c:\Users\Driptanil\anaconda3\lib\site-packages\pandas\io\parsers\readers.py", line 575, in _read
#     parser = TextFileReader(filepath_or_buffer, **kwds)
#   File "c:\Users\Driptanil\anaconda3\lib\site-packages\pandas\io\parsers\readers.py", line 933, in __init__
#     self._engine = self._make_engine(f, self.engine)
#   File "c:\Users\Driptanil\anaconda3\lib\site-packages\pandas\io\parsers\readers.py", line 1217, in _make_engine
#     self.handles = get_handle(  # type: ignore[call-overload]
#   File "c:\Users\Driptanil\anaconda3\lib\site-packages\pandas\io\common.py", line 789, in get_handle
#     handle = open(
# FileNotFoundError: [Errno 2] No such file or directory: '../data/None-USD.csv'
# Exception on /_dash-update-component [POST]
# Traceback (most recent call last):
#   File "c:\Users\Driptanil\anaconda3\lib\site-packages\flask\app.py", line 2447, in wsgi_app
#     response = self.full_dispatch_request()
#   File "c:\Users\Driptanil\anaconda3\lib\site-packages\flask\app.py", line 1952, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "c:\Users\Driptanil\anaconda3\lib\site-packages\flask\app.py", line 1821, in handle_user_exception
#     reraise(exc_type, exc_value, tb)
#   File "c:\Users\Driptanil\anaconda3\lib\site-packages\flask\_compat.py", line 39, in reraise
#     raise value
#   File "c:\Users\Driptanil\anaconda3\lib\site-packages\flask\app.py", line 1950, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "c:\Users\Driptanil\anaconda3\lib\site-packages\flask\app.py", line 1936, in dispatch_request
#     return self.view_functions[rule.endpoint](**req.view_args)
#   File "c:\Users\Driptanil\anaconda3\lib\site-packages\dash\dash.py", line 1274, in dispatch
#     ctx.run(
#   File "c:\Users\Driptanil\anaconda3\lib\site-packages\dash\_callback.py", line 440, in add_context
#     output_value = func(*func_args, **func_kwargs)  # %% callback invoked %%
#   File "C:\Users\Driptanil\AppData\Local\Temp\ipykernel_9964\205751449.py", line 8, in update_text
#     df = pd.read_csv(f'../data/{user_selected}-USD.csv')
#   File "c:\Users\Driptanil\anaconda3\lib\site-packages\pandas\util\_decorators.py", line 311, in wrapper
#     return func(*args, **kwargs)
#   File "c:\Users\Driptanil\anaconda3\lib\site-packages\pandas\io\parsers\readers.py", line 680, in read_csv
#     return _read(filepath_or_buffer, kwds)
#   File "c:\Users\Driptanil\anaconda3\lib\site-packages\pandas\io\parsers\readers.py", line 575, in _read
#     parser = TextFileReader(filepath_or_buffer, **kwds)
#   File "c:\Users\Driptanil\anaconda3\lib\site-packages\pandas\io\parsers\readers.py", line 933, in __init__
#     self._engine = self._make_engine(f, self.engine)
#   File "c:\Users\Driptanil\anaconda3\lib\site-packages\pandas\io\parsers\readers.py", line 1217, in _make_engine
#     self.handles = get_handle(  # type: ignore[call-overload]
#   File "c:\Users\Driptanil\anaconda3\lib\site-packages\pandas\io\common.py", line 789, in get_handle
#     handle = open(
# FileNotFoundError: [Errno 2] No such file or directory: '../data/None-USD.csv'
# Exception on /_dash-update-component [POST]
# Traceback (most recent call last):
#   File "c:\Users\Driptanil\anaconda3\lib\site-packages\flask\app.py", line 2447, in wsgi_app
#     response = self.full_dispatch_request()
#   File "c:\Users\Driptanil\anaconda3\lib\site-packages\flask\app.py", line 1952, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "c:\Users\Driptanil\anaconda3\lib\site-packages\flask\app.py", line 1821, in handle_user_exception
#     reraise(exc_type, exc_value, tb)
#   File "c:\Users\Driptanil\anaconda3\lib\site-packages\flask\_compat.py", line 39, in reraise
#     raise value
#   File "c:\Users\Driptanil\anaconda3\lib\site-packages\flask\app.py", line 1950, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "c:\Users\Driptanil\anaconda3\lib\site-packages\flask\app.py", line 1936, in dispatch_request
#     return self.view_functions[rule.endpoint](**req.view_args)
#   File "c:\Users\Driptanil\anaconda3\lib\site-packages\dash\dash.py", line 1274, in dispatch
#     ctx.run(
#   File "c:\Users\Driptanil\anaconda3\lib\site-packages\dash\_callback.py", line 440, in add_context
#     output_value = func(*func_args, **func_kwargs)  # %% callback invoked %%
#   File "C:\Users\Driptanil\AppData\Local\Temp\ipykernel_9964\205751449.py", line 8, in update_text
#     df = pd.read_csv(f'../data/{user_selected}-USD.csv')
#   File "c:\Users\Driptanil\anaconda3\lib\site-packages\pandas\util\_decorators.py", line 311, in wrapper
#     return func(*args, **kwargs)
#   File "c:\Users\Driptanil\anaconda3\lib\site-packages\pandas\io\parsers\readers.py", line 680, in read_csv
#     return _read(filepath_or_buffer, kwds)
#   File "c:\Users\Driptanil\anaconda3\lib\site-packages\pandas\io\parsers\readers.py", line 575, in _read
#     parser = TextFileReader(filepath_or_buffer, **kwds)
#   File "c:\Users\Driptanil\anaconda3\lib\site-packages\pandas\io\parsers\readers.py", line 933, in __init__
#     self._engine = self._make_engine(f, self.engine)
#   File "c:\Users\Driptanil\anaconda3\lib\site-packages\pandas\io\parsers\readers.py", line 1217, in _make_engine
#     self.handles = get_handle(  # type: ignore[call-overload]
#   File "c:\Users\Driptanil\anaconda3\lib\site-packages\pandas\io\common.py", line 789, in get_handle
#     handle = open(
# FileNotFoundError: [Errno 2] No such file or directory: '../data/None-USD.csv'
# Exception on /_dash-update-component [POST]
# Traceback (most recent call last):
#   File "c:\Users\Driptanil\anaconda3\lib\site-packages\flask\app.py", line 2447, in wsgi_app
#     response = self.full_dispatch_request()
#   File "c:\Users\Driptanil\anaconda3\lib\site-packages\flask\app.py", line 1952, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "c:\Users\Driptanil\anaconda3\lib\site-packages\flask\app.py", line 1821, in handle_user_exception
#     reraise(exc_type, exc_value, tb)
#   File "c:\Users\Driptanil\anaconda3\lib\site-packages\flask\_compat.py", line 39, in reraise
#     raise value
#   File "c:\Users\Driptanil\anaconda3\lib\site-packages\flask\app.py", line 1950, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "c:\Users\Driptanil\anaconda3\lib\site-packages\flask\app.py", line 1936, in dispatch_request
#     return self.view_functions[rule.endpoint](**req.view_args)
#   File "c:\Users\Driptanil\anaconda3\lib\site-packages\dash\dash.py", line 1274, in dispatch
#     ctx.run(
#   File "c:\Users\Driptanil\anaconda3\lib\site-packages\dash\_callback.py", line 440, in add_context
#     output_value = func(*func_args, **func_kwargs)  # %% callback invoked %%
#   File "C:\Users\Driptanil\AppData\Local\Temp\ipykernel_9964\205751449.py", line 8, in update_text
#     df = pd.read_csv(f'../data/{user_selected}-USD.csv')
#   File "c:\Users\Driptanil\anaconda3\lib\site-packages\pandas\util\_decorators.py", line 311, in wrapper
#     return func(*args, **kwargs)
#   File "c:\Users\Driptanil\anaconda3\lib\site-packages\pandas\io\parsers\readers.py", line 680, in read_csv
#     return _read(filepath_or_buffer, kwds)
#   File "c:\Users\Driptanil\anaconda3\lib\site-packages\pandas\io\parsers\readers.py", line 575, in _read
#     parser = TextFileReader(filepath_or_buffer, **kwds)
#   File "c:\Users\Driptanil\anaconda3\lib\site-packages\pandas\io\parsers\readers.py", line 933, in __init__
#     self._engine = self._make_engine(f, self.engine)
#   File "c:\Users\Driptanil\anaconda3\lib\site-packages\pandas\io\parsers\readers.py", line 1217, in _make_engine
#     self.handles = get_handle(  # type: ignore[call-overload]
#   File "c:\Users\Driptanil\anaconda3\lib\site-packages\pandas\io\common.py", line 789, in get_handle
#     handle = open(
# FileNotFoundError: [Errno 2] No such file or directory: '../data/None-USD.csv'
# Exception on /_dash-update-component [POST]
# Traceback (most recent call last):
#   File "c:\Users\Driptanil\anaconda3\lib\site-packages\flask\app.py", line 2447, in wsgi_app
#     response = self.full_dispatch_request()
#   File "c:\Users\Driptanil\anaconda3\lib\site-packages\flask\app.py", line 1952, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "c:\Users\Driptanil\anaconda3\lib\site-packages\flask\app.py", line 1821, in handle_user_exception
#     reraise(exc_type, exc_value, tb)
#   File "c:\Users\Driptanil\anaconda3\lib\site-packages\flask\_compat.py", line 39, in reraise
#     raise value
#   File "c:\Users\Driptanil\anaconda3\lib\site-packages\flask\app.py", line 1950, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "c:\Users\Driptanil\anaconda3\lib\site-packages\flask\app.py", line 1936, in dispatch_request
#     return self.view_functions[rule.endpoint](**req.view_args)
#   File "c:\Users\Driptanil\anaconda3\lib\site-packages\dash\dash.py", line 1274, in dispatch
#     ctx.run(
#   File "c:\Users\Driptanil\anaconda3\lib\site-packages\dash\_callback.py", line 440, in add_context
#     output_value = func(*func_args, **func_kwargs)  # %% callback invoked %%
#   File "C:\Users\Driptanil\AppData\Local\Temp\ipykernel_9964\205751449.py", line 8, in update_text
#     df = pd.read_csv(f'../data/{user_selected}-USD.csv')
#   File "c:\Users\Driptanil\anaconda3\lib\site-packages\pandas\util\_decorators.py", line 311, in wrapper
#     return func(*args, **kwargs)
#   File "c:\Users\Driptanil\anaconda3\lib\site-packages\pandas\io\parsers\readers.py", line 680, in read_csv
#     return _read(filepath_or_buffer, kwds)
#   File "c:\Users\Driptanil\anaconda3\lib\site-packages\pandas\io\parsers\readers.py", line 575, in _read
#     parser = TextFileReader(filepath_or_buffer, **kwds)
#   File "c:\Users\Driptanil\anaconda3\lib\site-packages\pandas\io\parsers\readers.py", line 933, in __init__
#     self._engine = self._make_engine(f, self.engine)
#   File "c:\Users\Driptanil\anaconda3\lib\site-packages\pandas\io\parsers\readers.py", line 1217, in _make_engine
#     self.handles = get_handle(  # type: ignore[call-overload]
#   File "c:\Users\Driptanil\anaconda3\lib\site-packages\pandas\io\common.py", line 789, in get_handle
#     handle = open(
# FileNotFoundError: [Errno 2] No such file or directory: '../data/None-USD.csv'
# Exception on /_dash-update-component [POST]
# Traceback (most recent call last):
#   File "c:\Users\Driptanil\anaconda3\lib\site-packages\flask\app.py", line 2447, in wsgi_app
#     response = self.full_dispatch_request()
#   File "c:\Users\Driptanil\anaconda3\lib\site-packages\flask\app.py", line 1952, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "c:\Users\Driptanil\anaconda3\lib\site-packages\flask\app.py", line 1821, in handle_user_exception
#     reraise(exc_type, exc_value, tb)
#   File "c:\Users\Driptanil\anaconda3\lib\site-packages\flask\_compat.py", line 39, in reraise
#     raise value
#   File "c:\Users\Driptanil\anaconda3\lib\site-packages\flask\app.py", line 1950, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "c:\Users\Driptanil\anaconda3\lib\site-packages\flask\app.py", line 1936, in dispatch_request
#     return self.view_functions[rule.endpoint](**req.view_args)
#   File "c:\Users\Driptanil\anaconda3\lib\site-packages\dash\dash.py", line 1274, in dispatch
#     ctx.run(
#   File "c:\Users\Driptanil\anaconda3\lib\site-packages\dash\_callback.py", line 440, in add_context
#     output_value = func(*func_args, **func_kwargs)  # %% callback invoked %%
#   File "C:\Users\Driptanil\AppData\Local\Temp\ipykernel_9964\205751449.py", line 8, in update_text
#     df = pd.read_csv(f'../data/{user_selected}-USD.csv')
#   File "c:\Users\Driptanil\anaconda3\lib\site-packages\pandas\util\_decorators.py", line 311, in wrapper
#     return func(*args, **kwargs)
#   File "c:\Users\Driptanil\anaconda3\lib\site-packages\pandas\io\parsers\readers.py", line 680, in read_csv
#     return _read(filepath_or_buffer, kwds)
#   File "c:\Users\Driptanil\anaconda3\lib\site-packages\pandas\io\parsers\readers.py", line 575, in _read
#     parser = TextFileReader(filepath_or_buffer, **kwds)
#   File "c:\Users\Driptanil\anaconda3\lib\site-packages\pandas\io\parsers\readers.py", line 933, in __init__
#     self._engine = self._make_engine(f, self.engine)
#   File "c:\Users\Driptanil\anaconda3\lib\site-packages\pandas\io\parsers\readers.py", line 1217, in _make_engine
#     self.handles = get_handle(  # type: ignore[call-overload]
#   File "c:\Users\Driptanil\anaconda3\lib\site-packages\pandas\io\common.py", line 789, in get_handle
#     handle = open(
# FileNotFoundError: [Errno 2] No such file or directory: '../data/None-USD.csv'
# Exception on /_dash-update-component [POST]
# Traceback (most recent call last):
#   File "c:\Users\Driptanil\anaconda3\lib\site-packages\flask\app.py", line 2447, in wsgi_app
#     response = self.full_dispatch_request()
#   File "c:\Users\Driptanil\anaconda3\lib\site-packages\flask\app.py", line 1952, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "c:\Users\Driptanil\anaconda3\lib\site-packages\flask\app.py", line 1821, in handle_user_exception
#     reraise(exc_type, exc_value, tb)
#   File "c:\Users\Driptanil\anaconda3\lib\site-packages\flask\_compat.py", line 39, in reraise
#     raise value
#   File "c:\Users\Driptanil\anaconda3\lib\site-packages\flask\app.py", line 1950, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "c:\Users\Driptanil\anaconda3\lib\site-packages\flask\app.py", line 1936, in dispatch_request
#     return self.view_functions[rule.endpoint](**req.view_args)
#   File "c:\Users\Driptanil\anaconda3\lib\site-packages\dash\dash.py", line 1274, in dispatch
#     ctx.run(
#   File "c:\Users\Driptanil\anaconda3\lib\site-packages\dash\_callback.py", line 440, in add_context
#     output_value = func(*func_args, **func_kwargs)  # %% callback invoked %%
#   File "C:\Users\Driptanil\AppData\Local\Temp\ipykernel_9964\205751449.py", line 8, in update_text
#     df = pd.read_csv(f'../data/{user_selected}-USD.csv')
#   File "c:\Users\Driptanil\anaconda3\lib\site-packages\pandas\util\_decorators.py", line 311, in wrapper
#     return func(*args, **kwargs)
#   File "c:\Users\Driptanil\anaconda3\lib\site-packages\pandas\io\parsers\readers.py", line 680, in read_csv
#     return _read(filepath_or_buffer, kwds)
#   File "c:\Users\Driptanil\anaconda3\lib\site-packages\pandas\io\parsers\readers.py", line 575, in _read
#     parser = TextFileReader(filepath_or_buffer, **kwds)
#   File "c:\Users\Driptanil\anaconda3\lib\site-packages\pandas\io\parsers\readers.py", line 933, in __init__
#     self._engine = self._make_engine(f, self.engine)
#   File "c:\Users\Driptanil\anaconda3\lib\site-packages\pandas\io\parsers\readers.py", line 1217, in _make_engine
#     self.handles = get_handle(  # type: ignore[call-overload]
#   File "c:\Users\Driptanil\anaconda3\lib\site-packages\pandas\io\common.py", line 789, in get_handle
#     handle = open(
# FileNotFoundError: [Errno 2] No such file or directory: '../data/None-USD.csv'
# Exception on /_dash-update-component [POST]
# Traceback (most recent call last):
#   File "c:\Users\Driptanil\anaconda3\lib\site-packages\flask\app.py", line 2447, in wsgi_app
#     response = self.full_dispatch_request()
#   File "c:\Users\Driptanil\anaconda3\lib\site-packages\flask\app.py", line 1952, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "c:\Users\Driptanil\anaconda3\lib\site-packages\flask\app.py", line 1821, in handle_user_exception
#     reraise(exc_type, exc_value, tb)
#   File "c:\Users\Driptanil\anaconda3\lib\site-packages\flask\_compat.py", line 39, in reraise
#     raise value
#   File "c:\Users\Driptanil\anaconda3\lib\site-packages\flask\app.py", line 1950, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "c:\Users\Driptanil\anaconda3\lib\site-packages\flask\app.py", line 1936, in dispatch_request
#     return self.view_functions[rule.endpoint](**req.view_args)
#   File "c:\Users\Driptanil\anaconda3\lib\site-packages\dash\dash.py", line 1274, in dispatch
#     ctx.run(
#   File "c:\Users\Driptanil\anaconda3\lib\site-packages\dash\_callback.py", line 440, in add_context
#     output_value = func(*func_args, **func_kwargs)  # %% callback invoked %%
#   File "C:\Users\Driptanil\AppData\Local\Temp\ipykernel_9964\205751449.py", line 8, in update_text
#     df = pd.read_csv(f'../data/{user_selected}-USD.csv')
#   File "c:\Users\Driptanil\anaconda3\lib\site-packages\pandas\util\_decorators.py", line 311, in wrapper
#     return func(*args, **kwargs)
#   File "c:\Users\Driptanil\anaconda3\lib\site-packages\pandas\io\parsers\readers.py", line 680, in read_csv
#     return _read(filepath_or_buffer, kwds)
#   File "c:\Users\Driptanil\anaconda3\lib\site-packages\pandas\io\parsers\readers.py", line 575, in _read
#     parser = TextFileReader(filepath_or_buffer, **kwds)
#   File "c:\Users\Driptanil\anaconda3\lib\site-packages\pandas\io\parsers\readers.py", line 933, in __init__
#     self._engine = self._make_engine(f, self.engine)
#   File "c:\Users\Driptanil\anaconda3\lib\site-packages\pandas\io\parsers\readers.py", line 1217, in _make_engine
#     self.handles = get_handle(  # type: ignore[call-overload]
#   File "c:\Users\Driptanil\anaconda3\lib\site-packages\pandas\io\common.py", line 789, in get_handle
#     handle = open(
# FileNotFoundError: [Errno 2] No such file or directory: '../data/None-USD.csv'
# Exception on /_dash-update-component [POST]
# Traceback (most recent call last):
#   File "c:\Users\Driptanil\anaconda3\lib\site-packages\flask\app.py", line 2447, in wsgi_app
#     response = self.full_dispatch_request()
#   File "c:\Users\Driptanil\anaconda3\lib\site-packages\flask\app.py", line 1952, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "c:\Users\Driptanil\anaconda3\lib\site-packages\flask\app.py", line 1821, in handle_user_exception
#     reraise(exc_type, exc_value, tb)
#   File "c:\Users\Driptanil\anaconda3\lib\site-packages\flask\_compat.py", line 39, in reraise
#     raise value
#   File "c:\Users\Driptanil\anaconda3\lib\site-packages\flask\app.py", line 1950, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "c:\Users\Driptanil\anaconda3\lib\site-packages\flask\app.py", line 1936, in dispatch_request
#     return self.view_functions[rule.endpoint](**req.view_args)
#   File "c:\Users\Driptanil\anaconda3\lib\site-packages\dash\dash.py", line 1274, in dispatch
#     ctx.run(
#   File "c:\Users\Driptanil\anaconda3\lib\site-packages\dash\_callback.py", line 440, in add_context
#     output_value = func(*func_args, **func_kwargs)  # %% callback invoked %%
#   File "C:\Users\Driptanil\AppData\Local\Temp\ipykernel_9964\205751449.py", line 8, in update_text
#     df = pd.read_csv(f'../data/{user_selected}-USD.csv')
#   File "c:\Users\Driptanil\anaconda3\lib\site-packages\pandas\util\_decorators.py", line 311, in wrapper
#     return func(*args, **kwargs)
#   File "c:\Users\Driptanil\anaconda3\lib\site-packages\pandas\io\parsers\readers.py", line 680, in read_csv
#     return _read(filepath_or_buffer, kwds)
#   File "c:\Users\Driptanil\anaconda3\lib\site-packages\pandas\io\parsers\readers.py", line 575, in _read
#     parser = TextFileReader(filepath_or_buffer, **kwds)
#   File "c:\Users\Driptanil\anaconda3\lib\site-packages\pandas\io\parsers\readers.py", line 933, in __init__
#     self._engine = self._make_engine(f, self.engine)
#   File "c:\Users\Driptanil\anaconda3\lib\site-packages\pandas\io\parsers\readers.py", line 1217, in _make_engine
#     self.handles = get_handle(  # type: ignore[call-overload]
#   File "c:\Users\Driptanil\anaconda3\lib\site-packages\pandas\io\common.py", line 789, in get_handle
#     handle = open(
# ...
#     raise value
#   File "c:\Users\Driptanil\anaconda3\lib\site-packages\flask\app.py", line 1950, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "c:\Users\Driptanil\anaconda3\lib\site-packages\flask\app.py", line 1936, in dispatch_request
#     return self.view_functions[rule.endpoint](**req.view_args)
#   File "c:\Users\Driptanil\anaconda3\lib\site-packages\dash\dash.py", line 1274, in dispatch
#     ctx.run(
#   File "c:\Users\Driptanil\anaconda3\lib\site-packages\dash\_callback.py", line 440, in add_context
#     output_value = func(*func_args, **func_kwargs)  # %% callback invoked %%
#   File "C:\Users\Driptanil\AppData\Local\Temp\ipykernel_9964\205751449.py", line 8, in update_text
#     df = pd.read_csv(f'../data/{user_selected}-USD.csv')
#   File "c:\Users\Driptanil\anaconda3\lib\site-packages\pandas\util\_decorators.py", line 311, in wrapper
#     return func(*args, **kwargs)
#   File "c:\Users\Driptanil\anaconda3\lib\site-packages\pandas\io\parsers\readers.py", line 680, in read_csv
#     return _read(filepath_or_buffer, kwds)
#   File "c:\Users\Driptanil\anaconda3\lib\site-packages\pandas\io\parsers\readers.py", line 575, in _read
#     parser = TextFileReader(filepath_or_buffer, **kwds)
#   File "c:\Users\Driptanil\anaconda3\lib\site-packages\pandas\io\parsers\readers.py", line 933, in __init__
#     self._engine = self._make_engine(f, self.engine)
#   File "c:\Users\Driptanil\anaconda3\lib\site-packages\pandas\io\parsers\readers.py", line 1217, in _make_engine
#     self.handles = get_handle(  # type: ignore[call-overload]
#   File "c:\Users\Driptanil\anaconda3\lib\site-packages\pandas\io\common.py", line 789, in get_handle
#     handle = open(
# FileNotFoundError: [Errno 2] No such file or directory: '../data/None-USD.csv'
# Exception on /_dash-update-component [POST]
# Traceback (most recent call last):
#   File "c:\Users\Driptanil\anaconda3\lib\site-packages\flask\app.py", line 2447, in wsgi_app
#     response = self.full_dispatch_request()
#   File "c:\Users\Driptanil\anaconda3\lib\site-packages\flask\app.py", line 1952, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "c:\Users\Driptanil\anaconda3\lib\site-packages\flask\app.py", line 1821, in handle_user_exception
#     reraise(exc_type, exc_value, tb)
#   File "c:\Users\Driptanil\anaconda3\lib\site-packages\flask\_compat.py", line 39, in reraise
#     raise value
#   File "c:\Users\Driptanil\anaconda3\lib\site-packages\flask\app.py", line 1950, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "c:\Users\Driptanil\anaconda3\lib\site-packages\flask\app.py", line 1936, in dispatch_request
#     return self.view_functions[rule.endpoint](**req.view_args)
#   File "c:\Users\Driptanil\anaconda3\lib\site-packages\dash\dash.py", line 1274, in dispatch
#     ctx.run(
#   File "c:\Users\Driptanil\anaconda3\lib\site-packages\dash\_callback.py", line 440, in add_context
#     output_value = func(*func_args, **func_kwargs)  # %% callback invoked %%
#   File "C:\Users\Driptanil\AppData\Local\Temp\ipykernel_9964\205751449.py", line 8, in update_text
#     df = pd.read_csv(f'../data/{user_selected}-USD.csv')
#   File "c:\Users\Driptanil\anaconda3\lib\site-packages\pandas\util\_decorators.py", line 311, in wrapper
#     return func(*args, **kwargs)
#   File "c:\Users\Driptanil\anaconda3\lib\site-packages\pandas\io\parsers\readers.py", line 680, in read_csv
#     return _read(filepath_or_buffer, kwds)
#   File "c:\Users\Driptanil\anaconda3\lib\site-packages\pandas\io\parsers\readers.py", line 575, in _read
#     parser = TextFileReader(filepath_or_buffer, **kwds)
#   File "c:\Users\Driptanil\anaconda3\lib\site-packages\pandas\io\parsers\readers.py", line 933, in __init__
#     self._engine = self._make_engine(f, self.engine)
#   File "c:\Users\Driptanil\anaconda3\lib\site-packages\pandas\io\parsers\readers.py", line 1217, in _make_engine
#     self.handles = get_handle(  # type: ignore[call-overload]
#   File "c:\Users\Driptanil\anaconda3\lib\site-packages\pandas\io\common.py", line 789, in get_handle
#     handle = open(
# FileNotFoundError: [Errno 2] No such file or directory: '../data/None-USD.csv'
# Exception on /_dash-update-component [POST]
# Traceback (most recent call last):
#   File "c:\Users\Driptanil\anaconda3\lib\site-packages\flask\app.py", line 2447, in wsgi_app
#     response = self.full_dispatch_request()
#   File "c:\Users\Driptanil\anaconda3\lib\site-packages\flask\app.py", line 1952, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "c:\Users\Driptanil\anaconda3\lib\site-packages\flask\app.py", line 1821, in handle_user_exception
#     reraise(exc_type, exc_value, tb)
#   File "c:\Users\Driptanil\anaconda3\lib\site-packages\flask\_compat.py", line 39, in reraise
#     raise value
#   File "c:\Users\Driptanil\anaconda3\lib\site-packages\flask\app.py", line 1950, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "c:\Users\Driptanil\anaconda3\lib\site-packages\flask\app.py", line 1936, in dispatch_request
#     return self.view_functions[rule.endpoint](**req.view_args)
#   File "c:\Users\Driptanil\anaconda3\lib\site-packages\dash\dash.py", line 1274, in dispatch
#     ctx.run(
#   File "c:\Users\Driptanil\anaconda3\lib\site-packages\dash\_callback.py", line 440, in add_context
#     output_value = func(*func_args, **func_kwargs)  # %% callback invoked %%
#   File "C:\Users\Driptanil\AppData\Local\Temp\ipykernel_9964\205751449.py", line 8, in update_text
#     df = pd.read_csv(f'../data/{user_selected}-USD.csv')
#   File "c:\Users\Driptanil\anaconda3\lib\site-packages\pandas\util\_decorators.py", line 311, in wrapper
#     return func(*args, **kwargs)
#   File "c:\Users\Driptanil\anaconda3\lib\site-packages\pandas\io\parsers\readers.py", line 680, in read_csv
#     return _read(filepath_or_buffer, kwds)
#   File "c:\Users\Driptanil\anaconda3\lib\site-packages\pandas\io\parsers\readers.py", line 575, in _read
#     parser = TextFileReader(filepath_or_buffer, **kwds)
#   File "c:\Users\Driptanil\anaconda3\lib\site-packages\pandas\io\parsers\readers.py", line 933, in __init__
#     self._engine = self._make_engine(f, self.engine)
#   File "c:\Users\Driptanil\anaconda3\lib\site-packages\pandas\io\parsers\readers.py", line 1217, in _make_engine
#     self.handles = get_handle(  # type: ignore[call-overload]
#   File "c:\Users\Driptanil\anaconda3\lib\site-packages\pandas\io\common.py", line 789, in get_handle
#     handle = open(
# FileNotFoundError: [Errno 2] No such file or directory: '../data/None-USD.csv'
# Exception on /_dash-update-component [POST]
# Traceback (most recent call last):
#   File "c:\Users\Driptanil\anaconda3\lib\site-packages\flask\app.py", line 2447, in wsgi_app
#     response = self.full_dispatch_request()
#   File "c:\Users\Driptanil\anaconda3\lib\site-packages\flask\app.py", line 1952, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "c:\Users\Driptanil\anaconda3\lib\site-packages\flask\app.py", line 1821, in handle_user_exception
#     reraise(exc_type, exc_value, tb)
#   File "c:\Users\Driptanil\anaconda3\lib\site-packages\flask\_compat.py", line 39, in reraise
#     raise value
#   File "c:\Users\Driptanil\anaconda3\lib\site-packages\flask\app.py", line 1950, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "c:\Users\Driptanil\anaconda3\lib\site-packages\flask\app.py", line 1936, in dispatch_request
#     return self.view_functions[rule.endpoint](**req.view_args)
#   File "c:\Users\Driptanil\anaconda3\lib\site-packages\dash\dash.py", line 1274, in dispatch
#     ctx.run(
#   File "c:\Users\Driptanil\anaconda3\lib\site-packages\dash\_callback.py", line 440, in add_context
#     output_value = func(*func_args, **func_kwargs)  # %% callback invoked %%
#   File "C:\Users\Driptanil\AppData\Local\Temp\ipykernel_9964\205751449.py", line 8, in update_text
#     df = pd.read_csv(f'../data/{user_selected}-USD.csv')
#   File "c:\Users\Driptanil\anaconda3\lib\site-packages\pandas\util\_decorators.py", line 311, in wrapper
#     return func(*args, **kwargs)
#   File "c:\Users\Driptanil\anaconda3\lib\site-packages\pandas\io\parsers\readers.py", line 680, in read_csv
#     return _read(filepath_or_buffer, kwds)
#   File "c:\Users\Driptanil\anaconda3\lib\site-packages\pandas\io\parsers\readers.py", line 575, in _read
#     parser = TextFileReader(filepath_or_buffer, **kwds)
#   File "c:\Users\Driptanil\anaconda3\lib\site-packages\pandas\io\parsers\readers.py", line 933, in __init__
#     self._engine = self._make_engine(f, self.engine)
#   File "c:\Users\Driptanil\anaconda3\lib\site-packages\pandas\io\parsers\readers.py", line 1217, in _make_engine
#     self.handles = get_handle(  # type: ignore[call-overload]
#   File "c:\Users\Driptanil\anaconda3\lib\site-packages\pandas\io\common.py", line 789, in get_handle
#     handle = open(
# FileNotFoundError: [Errno 2] No such file or directory: '../data/None-USD.csv'
# Exception on /_dash-update-component [POST]
# Traceback (most recent call last):
#   File "c:\Users\Driptanil\anaconda3\lib\site-packages\flask\app.py", line 2447, in wsgi_app
#     response = self.full_dispatch_request()
#   File "c:\Users\Driptanil\anaconda3\lib\site-packages\flask\app.py", line 1952, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "c:\Users\Driptanil\anaconda3\lib\site-packages\flask\app.py", line 1821, in handle_user_exception
#     reraise(exc_type, exc_value, tb)
#   File "c:\Users\Driptanil\anaconda3\lib\site-packages\flask\_compat.py", line 39, in reraise
#     raise value
#   File "c:\Users\Driptanil\anaconda3\lib\site-packages\flask\app.py", line 1950, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "c:\Users\Driptanil\anaconda3\lib\site-packages\flask\app.py", line 1936, in dispatch_request
#     return self.view_functions[rule.endpoint](**req.view_args)
#   File "c:\Users\Driptanil\anaconda3\lib\site-packages\dash\dash.py", line 1274, in dispatch
#     ctx.run(
#   File "c:\Users\Driptanil\anaconda3\lib\site-packages\dash\_callback.py", line 440, in add_context
#     output_value = func(*func_args, **func_kwargs)  # %% callback invoked %%
#   File "C:\Users\Driptanil\AppData\Local\Temp\ipykernel_9964\205751449.py", line 8, in update_text
#     df = pd.read_csv(f'../data/{user_selected}-USD.csv')
#   File "c:\Users\Driptanil\anaconda3\lib\site-packages\pandas\util\_decorators.py", line 311, in wrapper
#     return func(*args, **kwargs)
#   File "c:\Users\Driptanil\anaconda3\lib\site-packages\pandas\io\parsers\readers.py", line 680, in read_csv
#     return _read(filepath_or_buffer, kwds)
#   File "c:\Users\Driptanil\anaconda3\lib\site-packages\pandas\io\parsers\readers.py", line 575, in _read
#     parser = TextFileReader(filepath_or_buffer, **kwds)
#   File "c:\Users\Driptanil\anaconda3\lib\site-packages\pandas\io\parsers\readers.py", line 933, in __init__
#     self._engine = self._make_engine(f, self.engine)
#   File "c:\Users\Driptanil\anaconda3\lib\site-packages\pandas\io\parsers\readers.py", line 1217, in _make_engine
#     self.handles = get_handle(  # type: ignore[call-overload]
#   File "c:\Users\Driptanil\anaconda3\lib\site-packages\pandas\io\common.py", line 789, in get_handle
#     handle = open(
# FileNotFoundError: [Errno 2] No such file or directory: '../data/None-USD.csv'
# Exception on /_dash-update-component [POST]
# Traceback (most recent call last):
#   File "c:\Users\Driptanil\anaconda3\lib\site-packages\flask\app.py", line 2447, in wsgi_app
#     response = self.full_dispatch_request()
#   File "c:\Users\Driptanil\anaconda3\lib\site-packages\flask\app.py", line 1952, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "c:\Users\Driptanil\anaconda3\lib\site-packages\flask\app.py", line 1821, in handle_user_exception
#     reraise(exc_type, exc_value, tb)
#   File "c:\Users\Driptanil\anaconda3\lib\site-packages\flask\_compat.py", line 39, in reraise
#     raise value
#   File "c:\Users\Driptanil\anaconda3\lib\site-packages\flask\app.py", line 1950, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "c:\Users\Driptanil\anaconda3\lib\site-packages\flask\app.py", line 1936, in dispatch_request
#     return self.view_functions[rule.endpoint](**req.view_args)
#   File "c:\Users\Driptanil\anaconda3\lib\site-packages\dash\dash.py", line 1274, in dispatch
#     ctx.run(
#   File "c:\Users\Driptanil\anaconda3\lib\site-packages\dash\_callback.py", line 440, in add_context
#     output_value = func(*func_args, **func_kwargs)  # %% callback invoked %%
#   File "C:\Users\Driptanil\AppData\Local\Temp\ipykernel_9964\205751449.py", line 8, in update_text
#     df = pd.read_csv(f'../data/{user_selected}-USD.csv')
#   File "c:\Users\Driptanil\anaconda3\lib\site-packages\pandas\util\_decorators.py", line 311, in wrapper
#     return func(*args, **kwargs)
#   File "c:\Users\Driptanil\anaconda3\lib\site-packages\pandas\io\parsers\readers.py", line 680, in read_csv
#     return _read(filepath_or_buffer, kwds)
#   File "c:\Users\Driptanil\anaconda3\lib\site-packages\pandas\io\parsers\readers.py", line 575, in _read
#     parser = TextFileReader(filepath_or_buffer, **kwds)
#   File "c:\Users\Driptanil\anaconda3\lib\site-packages\pandas\io\parsers\readers.py", line 933, in __init__
#     self._engine = self._make_engine(f, self.engine)
#   File "c:\Users\Driptanil\anaconda3\lib\site-packages\pandas\io\parsers\readers.py", line 1217, in _make_engine
#     self.handles = get_handle(  # type: ignore[call-overload]
#   File "c:\Users\Driptanil\anaconda3\lib\site-packages\pandas\io\common.py", line 789, in get_handle
#     handle = open(
# FileNotFoundError: [Errno 2] No such file or directory: '../data/None-USD.csv'
# Exception on /_dash-update-component [POST]
# Traceback (most recent call last):
#   File "c:\Users\Driptanil\anaconda3\lib\site-packages\flask\app.py", line 2447, in wsgi_app
#     response = self.full_dispatch_request()
#   File "c:\Users\Driptanil\anaconda3\lib\site-packages\flask\app.py", line 1952, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "c:\Users\Driptanil\anaconda3\lib\site-packages\flask\app.py", line 1821, in handle_user_exception
#     reraise(exc_type, exc_value, tb)
#   File "c:\Users\Driptanil\anaconda3\lib\site-packages\flask\_compat.py", line 39, in reraise
#     raise value
#   File "c:\Users\Driptanil\anaconda3\lib\site-packages\flask\app.py", line 1950, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "c:\Users\Driptanil\anaconda3\lib\site-packages\flask\app.py", line 1936, in dispatch_request
#     return self.view_functions[rule.endpoint](**req.view_args)
#   File "c:\Users\Driptanil\anaconda3\lib\site-packages\dash\dash.py", line 1274, in dispatch
#     ctx.run(
#   File "c:\Users\Driptanil\anaconda3\lib\site-packages\dash\_callback.py", line 440, in add_context
#     output_value = func(*func_args, **func_kwargs)  # %% callback invoked %%
#   File "C:\Users\Driptanil\AppData\Local\Temp\ipykernel_9964\205751449.py", line 8, in update_text
#     df = pd.read_csv(f'../data/{user_selected}-USD.csv')
#   File "c:\Users\Driptanil\anaconda3\lib\site-packages\pandas\util\_decorators.py", line 311, in wrapper
#     return func(*args, **kwargs)
#   File "c:\Users\Driptanil\anaconda3\lib\site-packages\pandas\io\parsers\readers.py", line 680, in read_csv
#     return _read(filepath_or_buffer, kwds)
#   File "c:\Users\Driptanil\anaconda3\lib\site-packages\pandas\io\parsers\readers.py", line 575, in _read
#     parser = TextFileReader(filepath_or_buffer, **kwds)
#   File "c:\Users\Driptanil\anaconda3\lib\site-packages\pandas\io\parsers\readers.py", line 933, in __init__
#     self._engine = self._make_engine(f, self.engine)
#   File "c:\Users\Driptanil\anaconda3\lib\site-packages\pandas\io\parsers\readers.py", line 1217, in _make_engine
#     self.handles = get_handle(  # type: ignore[call-overload]
#   File "c:\Users\Driptanil\anaconda3\lib\site-packages\pandas\io\common.py", line 789, in get_handle
#     handle = open(
# FileNotFoundError: [Errno 2] No such file or directory: '../data/None-USD.csv'
# 127.0.0.1 - - [16/Jan/2023 04:25:50] "POST /_dash-update-component HTTP/1.1" 500 -
# 127.0.0.1 - - [16/Jan/2023 04:25:52] "POST /_dash-update-component HTTP/1.1" 200 -
